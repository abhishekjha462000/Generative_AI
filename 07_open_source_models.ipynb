# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv

load_dotenv()


# Connects to Hugging Face's servers to run the open-source Mistral model
llm = HuggingFaceEndpoint(
    repo_id="Qwen/Qwen2.5-7B-Instruct",
    task = "text-generation",
    temperature = 0.8
)

model = ChatHuggingFace(llm = llm)
result = model.invoke("What is Love in short?")

type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
result
# Out:
# AIMessage(content='Love is a strong feeling of deep affection, protectiveness, warmth, and respect for another person. It can also include a deep romantic or sexual attraction. Love can inspire people to make sacrifices for each other and can be expressed in various ways, from simple acts of kindness to profound gestures of support and commitment.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 35, 'total_tokens': 98}, 'model_name': 'Qwen/Qwen2.5-7B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d79a8-2a19-77f1-86e2-4dde03678d89-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 35, 'output_tokens': 63, 'total_tokens': 98})

# %%
print(result.content)
# Out:
# Love is a strong feeling of deep affection, protectiveness, warmth, and respect for another person. It can also include a deep romantic or sexual attraction. Love can inspire people to make sacrifices for each other and can be expressed in various ways, from simple acts of kindness to profound gestures of support and commitment.

# %% [markdown]
# # Using Ollama Chat Model

# %%
from langchain_ollama import ChatOllama

chat_model = ChatOllama(model = "llama3.2:1b")

# %%
result = chat_model.invoke("What is love in short?")

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
print(result.content)
# Out:
# Love is a complex and multifaceted emotion that can be described in many ways, but at its core, it's a strong feeling of affection, attachment, or desire for another person. It can be romantic, platonic, familial, or selfless, and encompasses a range of emotions, from euphoria to vulnerability.
